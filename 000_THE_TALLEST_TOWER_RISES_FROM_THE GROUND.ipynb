# %%
import pandas as pd

# %%
# it's just a gift aiming the use of protypes and data structures
# kevin helped a lot and i'd like to share it!

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('2AFGPdNn4FM', width=600, height=300, align="center")

# %%
YouTubeVideo('YPItfQ87qjM', width=600, height=300, align="center")

# %%
YouTubeVideo('ht5buXUMqkQ', width=600, height=300, align="center")

# %%
YouTubeVideo('ht5buXUMqkQ', width=600, height=300, align="center")

# %%
YouTubeVideo('P_q0tkYqvSk', width=600, height=300, align="center")
