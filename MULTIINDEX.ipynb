# %%
import pandas as pd

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('tcRGa2soc-c', width=600, height=300, align="center")

# %%
stocks = pd.read_csv('http://bit.ly/smallstocks')

# %%
stocks
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
stocks.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
stocks.groupby('Symbol').Close.mean()
# Out:
# Symbol
# AAPL    112.856667
# CSCO     31.480000
# MSFT     57.433333
# Name: Close, dtype: float64

# %%
ser=stocks.groupby(['Symbol', 'Date']).Close.mean()

# %%
ser
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
ser.index
# Out:
# MultiIndex([('AAPL', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('AAPL', '2016-10-05'),
#             ('CSCO', '2016-10-03'),
#             ('CSCO', '2016-10-04'),
#             ('CSCO', '2016-10-05'),
#             ('MSFT', '2016-10-03'),
#             ('MSFT', '2016-10-04'),
#             ('MSFT', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
ser.unstack()
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
stocks.pivot_table(values='Close', index='Symbol', columns='Date')
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
ser
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
#sellect

# %%
ser.loc['AAPL']
# Out:
# Date
# 2016-10-03    112.52
# 2016-10-04    113.00
# 2016-10-05    113.05
# Name: Close, dtype: float64

# %%
ser.loc['AAPL', '2016-10-03']
# Out:
# 112.52

# %%
ser.loc[:, '2016-10-03']
# Out:
# Symbol
# AAPL    112.52
# CSCO     31.50
# MSFT     57.42
# Name: Close, dtype: float64

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
stocks.set_index(['Symbol', 'Date'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14248/3943399896.py in <module>
# ----> 1 stocks.set_index(['Symbol', 'Date'], inplace=True)
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5444
#    5445         if missing:
# -> 5446             raise KeyError(f"None of {missing} are in the columns")
#    5447
#    5448         if inplace:
#
# KeyError: "None of ['Symbol', 'Date'] are in the columns"

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
stocks.sort_index(inplace=True)

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
stocks.loc['AAPL']
# Out:
#              Close    Volume
# Date
# 2016-10-03  112.52  21701800
# 2016-10-04  113.00  29736800
# 2016-10-05  113.05  21453100

# %%
stocks.loc[('AAPL', '2016-10-03'), :]
# Out:
# Close          112.52
# Volume    21701800.00
# Name: (AAPL, 2016-10-03), dtype: float64

# %%
stocks.loc[('AAPL', '2016-10-03'), 'Close']
# Out:
# 112.52

# %%
stocks.loc[(['AAPL', 'MSFT'], '2016-10-03'),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500

# %%
stocks.loc[(['AAPL', 'MSFT'], '2016-10-03'),'Close']
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
# MSFT    2016-10-03     57.42
# Name: Close, dtype: float64

# %%
stocks.loc[('AAPL',  ['2016-10-03','2016-10-04'] ),'Close']
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
# Name: Close, dtype: float64

# %%
stocks.loc[(slice(None),  ['2016-10-03','2016-10-04'] ),'Close']
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
# Name: Close, dtype: float64

# %%
#stocks.loc[(:,  ['2016-10-03','2016-10-04'] ),'Close'] won't work!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ###### MERGING MULTILEVEL DATA

# %%
close = pd.read_csv('http://bit.ly/smallstocks', usecols=[0,1,3], index_col=['Symbol', 'Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14248/3504862610.py in <module>
# ----> 1 close = pd.read_csv('http://bit.ly/smallstocks', usecols=[0,1,3], index_col=['Symbol', 'Date'])
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#     148             if len(self.names) < len(usecols):  # type: ignore[has-type]
#     149                 # error: Cannot determine type of 'names'
# --> 150                 self._validate_usecols_names(
#     151                     usecols,
#     152                     self.names,  # type: ignore[has-type]
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\base_parser.py in _validate_usecols_names(self, usecols, names)
#     864         missing = [c for c in usecols if c not in names]
#     865         if len(missing) > 0:
# --> 866             raise ValueError(
#     867                 f"Usecols do not match columns, columns expected but not found: "
#     868                 f"{missing}"
#
# ValueError: Usecols do not match columns, columns expected but not found: [0, 1, 3]

# %%
close

# %%
volume = pd.read_csv('http://bit.ly/smallstocks', usecols=[0,2,3], index_col=['Symbol', 'Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14248/1052809608.py in <module>
# ----> 1 volume = pd.read_csv('http://bit.ly/smallstocks', usecols=[0,2,3], index_col=['Symbol', 'Date'])
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#     148             if len(self.names) < len(usecols):  # type: ignore[has-type]
#     149                 # error: Cannot determine type of 'names'
# --> 150                 self._validate_usecols_names(
#     151                     usecols,
#     152                     self.names,  # type: ignore[has-type]
#
# C:\DADOS\CONDA3\lib\site-packages\pandas\io\parsers\base_parser.py in _validate_usecols_names(self, usecols, names)
#     864         missing = [c for c in usecols if c not in names]
#     865         if len(missing) > 0:
# --> 866             raise ValueError(
#     867                 f"Usecols do not match columns, columns expected but not found: "
#     868                 f"{missing}"
#
# ValueError: Usecols do not match columns, columns expected but not found: [0, 2, 3]

# %%
volume

# %%
both = pd.merge(close, volume, left_index=True, right_index=True)
