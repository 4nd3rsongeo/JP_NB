# %%
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt

# %%
chart_size=[10, 10]

# %%
path = "C:\DADOS\ANDERSON\PROJ_VULCAN\SN3_1121\Arq_Vulcan\\"

# %%
fso = pd.read_csv(path + "n3flp_cac_entry.csv", low_memory=False, na_values='-99', encoding="latin1")
fso.rename(columns=str.upper, inplace=True)

# %%
cac = pd.read_csv(path + "sn3flp_fso_assay.csv", low_memory=False, na_values='-99', encoding="latin1")
cac.rename(columns=str.upper, inplace=True)

# %%
from ipywidgets import interactive

def bin_widget(bw=0.1):
    sea.histplot(data=fso["FEGL"],binwidth=bw,kde=True, color='r')

# %%
interactive(bin_widget, bw=(0, 1, 0.05))
# Out:
# interactive(children=(FloatSlider(value=0.1, description='bw', max=1.0, step=0.05), Output()), _dom_classes=('…

# %%
fig, ax = plt.subplots(figsize=chart_size)
sea.histplot(data=fso["FEGL"],binwidth=1,kde=True, color='r')
sea.histplot(data=cac["FEGL"],binwidth=1,kde=True, color='g')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SAMPLE COUNT')
ax.set_title('OXIDE BEARING ROCKS FEGL')

plt.show()
fig.savefig('TEST_HISTOGRAM_FEGL.jpeg', transparent=None)

# %%
fig, ax = plt.subplots(figsize=chart_size)
sea.boxplot(data=fso["FEGL"], color='r')
sea.boxplot(data=cac["FEGL"], color='g')
# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_ylabel('SAMPLE COUNT')
#ax.set_title('OXIDE BEARING ROCKS FEGL')

plt.show()
fig.savefig('TEST_HISTOGRAM_FEGL.jpeg', transparent=None)

# %%
fig, ax = plt.subplots(figsize=chart_size)

bw=0.1
sea.kdeplot(data=fso,x='FEGL', color='r', bw=bw)
sea.kdeplot(data=cac,x='FEGL', color='g',bw=bw)
#sea.kdeplot(data=df_box3,x=grade,hue=breakdown, common_norm=False, palette=litocolor, alpha=.5)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SAMPLE COUNT')
ax.set_title('OXIDE BEARING ROCKS FEGL')

plt.show()
fig.savefig('TEST_COMPOSITE_HISTOGRAM_FEGL.jpeg', transparent=None)
# Out:
# C:\DADOS\CONDA3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\DADOS\CONDA3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=chart_size)
#sea.stripplot(x=fso.FEGL, y=fso.GEOCOD)
sea.stripplot(x=cac.FEGL, y=cac.CLI, size=5, alpha=0.8, marker='.', jitter=0.5)
# Out:
# <AxesSubplot:xlabel='FEGL', ylabel='CLI'>

# %%
fso.columns
# Out:
# Index(['COMPID', 'DHID', 'MIDX', 'MIDY', 'MIDZ', 'LENGTH', 'FROM', 'TO',
#        'GEOCOD', 'GEOCD2',
#        ...
#        'AFE3', 'ASI3', 'AP3', 'AAL3', 'AMN3', 'APF3', 'ACA3', 'AMG3', 'ATI3',
#        'SETOR'],
#       dtype='object', length=104)
